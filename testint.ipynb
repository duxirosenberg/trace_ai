# %%
import pandas as pd
import json
import ollama
from datetime import datetime
from pydantic import BaseModel

# ----- Transaction Schema -----
class TransactionBase(BaseModel):
    id_bank_account: int
    date: datetime
    amount: float
    currency: str
    description: str
    recipient: str
    raw_data: str

# %%
def detect_delimiter(file_path):
    """Detects delimiter by analyzing the first few lines of the file."""
    with open(file_path, 'r', encoding='utf-8') as f:
        sample = f.read(1024)  # Read a small portion of the file
    delimiters = [',', ';', '\t', '|']
    return max(delimiters, key=lambda d: sample.count(d))

# %%
file_revolut = 'revolut_chf.csv'
file_zkb = 'zkb.csv'

delimiter = detect_delimiter(file_revolut)
delimiter_zkb = detect_delimiter(file_zkb)

df = pd.read_csv(file_revolut, delimiter=delimiter, dtype=str)
df_zkb = pd.read_csv(file_zkb, delimiter=delimiter_zkb, dtype=str)

# %%
def generate_mapping_prompt(headers, sample_data):
    """Generates a highly strict prompt for AI-based column mapping, including a data sample."""
    return f'''
    You are an AI model tasked with mapping CSV column headers to a predefined schema.
    Your response **must be strictly** a JSON dictionary mapping the schema fields to the correct column names from the input data.
    
    The only acceptable format is:
    {{
        "date": "<original_column_name_1>",
        "amount": "<original_column_name_2>",
        "currency": "<original_column_name_3>",
        "description": "<original_column_name_4>",
        "recipient": "<original_column_name_5>"
    }}
    
    If no column from the input matches a given field, set its value to `null`.
    
    Instructions:
    - Your response **must** be a valid JSON dictionary and contain **only** the mappings.
    - **DO NOT** include any additional text, comments, explanations, or formatting issues.
    - The values in your response must be exact column names from the input headers or `null` if a match is not found.
    - Ensure that every key-value pair follows the expected schema strictly.
    
    Here is a small sample of the data for better understanding:
    {json.dumps(sample_data, indent=2, ensure_ascii=False)}
    
    Given these column headers: {headers}, provide only a JSON mapping in the exact format above.
    '''

# %%
def parse_csv(file_path, sample_size=5):
    """Loads CSV file with AI-assisted schema mapping, providing a sample of the data."""
    delimiter = detect_delimiter(file_path)
    df = pd.read_csv(file_path, delimiter=delimiter, dtype=str)
    
    # Select a small sample of data to provide context
    sample_data = df.sample(sample_size).to_dict(orient='records')
    
    prompt = generate_mapping_prompt(list(df.columns), sample_data)
    result = ollama.generate(model="llama3:8b", prompt=prompt)
    
    try:
        column_mapping = json.loads(result.get('response'))  # Ensure we only get pure JSON
        print(column_mapping)
    except json.JSONDecodeError:
        raise ValueError("AI response could not be parsed as JSON")
    
    # Create a new transactions DataFrame
    transactions_data = []
    for _, row in df.iterrows():
        transaction = {
            "date": row[column_mapping["date"]] if column_mapping["date"] else None,
            "amount": float(row[column_mapping["amount"]]) if column_mapping["amount"] else None,
            "currency": row[column_mapping["currency"]] if column_mapping["currency"] else None,
            "description": row[column_mapping["description"]] if column_mapping["description"] else None,
            "recipient": row[column_mapping["recipient"]] if column_mapping["recipient"] else None,
            "raw_data": json.dumps(row.to_dict(), ensure_ascii=False)
        }
        transactions_data.append(transaction)
    
    transactions_df = pd.DataFrame(transactions_data)
    transactions_df['date'] = pd.to_datetime(transactions_df['date'], errors='coerce')
    
    #return [TransactionBase(**row) for row in transactions_df.to_dict(orient='records')]
    return transactions_df

# %%
parse_csv("csvs/revolut_chf.csv")
# Out:
# {'date': 'Started Date', 'amount': 'Amount', 'currency': 'Currency', 'description': 'Description', 'recipient': None}
#                   date  amount currency            description recipient  \
# 0  2025-02-03 14:30:27   -25.8      CHF                   Coop      None
# 1  2025-02-04 08:20:13    -7.8      CHF             SBB Ticket      None
# 2  2025-02-05 15:10:42   -12.5      CHF                 Migros      None
# 3  2025-02-08 20:14:38   -67.3      CHF  Restaurant Alpenblick      None
# 4  2025-02-11 09:45:33   -15.4      CHF                 Denner      None
# 5  2025-02-12 17:05:50    -3.2      CHF               EasyPark      None
# 6  2025-02-13 08:14:27    -5.5      CHF        Kiosk Zurich HB      None
# 7  2025-02-16 13:27:40  -120.0      CHF                Galaxus      None
# 8  2025-02-17 21:18:15  -199.5      CHF            Hotel Basel      None
# 9  2025-02-18 19:32:20    -9.8      CHF              ZFV Mensa      None
# 10 2025-02-20 14:22:53   -85.9      CHF        Skinfit Schweiz      None
# 11 2025-02-21 11:40:18    -7.6      CHF   University of Zurich      None
# 12 2025-02-23 09:55:41   -23.4      CHF                 Denner      None
# 13 2025-02-23 18:47:50   -15.3      CHF                   Coop      None
#
#                                              raw_data
# 0   {"Type": "CARD_PAYMENT", "Product": "Savings",...
# 1   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 2   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 3   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 4   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 5   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 6   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 7   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 8   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 9   {"Type": "CARD_PAYMENT", "Product": "Current",...
# 10  {"Type": "CARD_PAYMENT", "Product": "Current",...
# 11  {"Type": "CARD_PAYMENT", "Product": "Current",...
# 12  {"Type": "CARD_PAYMENT", "Product": "Current",...
# 13  {"Type": "CARD_PAYMENT", "Product": "Current",...

# %%
parse_csv("csvs/zkb.csv")
# Out:
# {'date': 'Date', 'amount': 'Debit CHF', 'currency': None, 'description': 'Booking text', 'recipient': None}
# /var/folders/w_/35n4rz_56djd5_n1l0741mjw0000gn/T/ipykernel_42992/3744394485.py:32: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   transactions_df['date'] = pd.to_datetime(transactions_df['date'], errors='coerce')
#          date  amount currency                            description  \
# 0  2025-02-19    3.20     None       Debit TWINT: SBB EASYRIDE ZURICH
# 1  2025-02-18   15.40     None                 Debit TWINT: COOP CITY
# 2  2025-02-17   22.75     None             Debit TWINT: MIGROS ZURICH
# 3  2025-02-16    6.80     None       Debit TWINT: STARBUCKS ZURICH HB
# 4  2025-02-15   12.95     None           Debit TWINT: DENNER OERLIKON
# 5  2025-02-14    9.20     None      Debit TWINT: ZFV MENSA ETH ZURICH
# 6  2025-02-13   17.50     None           Debit TWINT: APOTHEKE ZURICH
# 7  2025-02-12   42.90     None           Debit TWINT: EASYJET ZRH-GVA
# 8  2025-02-11    4.50     None     Debit TWINT: TCHIBO BAHNHOFSTRASSE
# 9  2025-02-10   28.40     None       Debit TWINT: PIZZERIA DA MICHELE
# 10 2025-02-09    5.80     None        Debit TWINT: GELATERIA DI BERNA
# 11 2025-02-08   81.00     None           Debit TWINT: ASVZ MEMBERSHIP
# 12 2025-02-07    8.60     None        Debit TWINT: UZH PLATTENSTRASSE
# 13 2025-02-06   17.90     None           Debit TWINT: CINEMAXX ZURICH
# 14 2025-02-05   12.40     None       Debit TWINT: JELMOLI FOOD MARKET
# 15 2025-02-04   47.30     None          Debit TWINT: SHELL TANKSTELLE
# 16 2025-02-03    9.70     None         Debit TWINT: BÄCKEREI BUCHMANN
# 17 2025-02-02   21.00     None           Debit TWINT: BARFÜSSER BASEL
# 18 2025-02-01   38.50     None        Debit TWINT: CLUB FUTURE ZURICH
# 19 2025-01-31   13.90     None        Debit TWINT: MC DONALD'S ZURICH
# 20 2025-01-30   22.10     None            Debit TWINT: BIO LADEN BERN
# 21 2025-01-29   56.00     None  Debit TWINT: SBB TICKET ZURICH-LUGANO
# 22 2025-01-28   18.30     None          Debit TWINT: AMAVITA APOTHEKE
# 23 2025-01-27   24.20     None      Debit TWINT: COOP ZÜRICH OERLIKON
# 24 2025-01-26    9.50     None            Debit TWINT: SV GROUP MENSA
# 25 2025-01-25    7.30     None           Debit TWINT: BIPA WINTERTHUR
# 26 2025-01-24   11.60     None          Debit TWINT: MIGROS TAKE AWAY
# 27 2025-01-23   29.40     None            Debit TWINT: LIDL SCHLIEREN
# 28 2025-01-22   17.20     None         Debit TWINT: RIMINI BAR ZURICH
# 29 2025-01-21   23.80     None          Debit TWINT: UBER EATS ZURICH
# 30 2025-01-20   36.90     None           Debit TWINT: NESPRESSO STORE
# 31 2025-01-19   13.30     None              Debit TWINT: BAZAR ZURICH
#
#    recipient                                           raw_data
# 0       None  {"Date": "19.02.2025", "Booking text": "Debit ...
# 1       None  {"Date": "18.02.2025", "Booking text": "Debit ...
# 2       None  {"Date": "17.02.2025", "Booking text": "Debit ...
# 3       None  {"Date": "16.02.2025", "Booking text": "Debit ...
# 4       None  {"Date": "15.02.2025", "Booking text": "Debit ...
# 5       None  {"Date": "14.02.2025", "Booking text": "Debit ...
# 6       None  {"Date": "13.02.2025", "Booking text": "Debit ...
# 7       None  {"Date": "12.02.2025", "Booking text": "Debit ...
# 8       None  {"Date": "11.02.2025", "Booking text": "Debit ...
# 9       None  {"Date": "10.02.2025", "Booking text": "Debit ...
# 10      None  {"Date": "09.02.2025", "Booking text": "Debit ...
# 11      None  {"Date": "08.02.2025", "Booking text": "Debit ...
# 12      None  {"Date": "07.02.2025", "Booking text": "Debit ...
# 13      None  {"Date": "06.02.2025", "Booking text": "Debit ...
# 14      None  {"Date": "05.02.2025", "Booking text": "Debit ...
# 15      None  {"Date": "04.02.2025", "Booking text": "Debit ...
# 16      None  {"Date": "03.02.2025", "Booking text": "Debit ...
# 17      None  {"Date": "02.02.2025", "Booking text": "Debit ...
# 18      None  {"Date": "01.02.2025", "Booking text": "Debit ...
# 19      None  {"Date": "31.01.2025", "Booking text": "Debit ...
# 20      None  {"Date": "30.01.2025", "Booking text": "Debit ...
# 21      None  {"Date": "29.01.2025", "Booking text": "Debit ...
# 22      None  {"Date": "28.01.2025", "Booking text": "Debit ...
# 23      None  {"Date": "27.01.2025", "Booking text": "Debit ...
# 24      None  {"Date": "26.01.2025", "Booking text": "Debit ...
# 25      None  {"Date": "25.01.2025", "Booking text": "Debit ...
# 26      None  {"Date": "24.01.2025", "Booking text": "Debit ...
# 27      None  {"Date": "23.01.2025", "Booking text": "Debit ...
# 28      None  {"Date": "22.01.2025", "Booking text": "Debit ...
# 29      None  {"Date": "21.01.2025", "Booking text": "Debit ...
# 30      None  {"Date": "20.01.2025", "Booking text": "Debit ...
# 31      None  {"Date": "19.01.2025", "Booking text": "Debit ...

# %%
parse_csv('csvs/n26.csv')
# Out:
# {'date': 'Booking Date', 'amount': 'Amount (CHF)', 'currency': 'Original Currency', 'description': 'Partner Name', 'recipient': None}
#          date  amount currency            description recipient  \
# 0  2025-02-02 -139.00      CHF              Coop City      None
# 1  2025-02-02   -5.25      CHF          Migros Zürich      None
# 2  2025-02-02  -75.00      CHF               UBS Bank      None
# 3  2025-02-02  -48.00      CHF              Kino Maxx      None
# 4  2025-02-02  -13.90      CHF       Hiltl Restaurant      None
# 5  2025-02-02  -16.80      CHF         Coffee Fellows      None
# 6  2025-02-02  -15.50      CHF              ApoZurich      None
# 7  2025-02-03  -21.30      CHF            SBB Parking      None
# 8  2025-02-03   -9.20      CHF                Jelmoli      None
# 9  2025-02-04  -18.75      CHF      Bäckerei Buchmann      None
# 10 2025-02-04  -22.50      CHF             Zurich Gym      None
# 11 2025-02-04   -3.25      CHF             VOI Zürich      None
# 12 2025-02-05  -49.80      CHF       Shell Tankstelle      None
# 13 2025-02-05  -19.50      CHF              Sushi Zen      None
# 14 2025-02-07  -11.20      NaN               Swisscom      None
# 15 2025-02-08   -2.95      CHF                 Denner      None
# 16 2025-02-09  -18.90      CHF    McDonalds Zürich HB      None
# 17 2025-02-09   -6.80      CHF        AGIP Tankstelle      None
# 18 2025-02-10  -27.50      CHF     Tennis Club Zürich      None
# 19 2025-02-10  -21.00      CHF              Barfüsser      None
# 20 2025-02-11  -13.80      CHF            Tacos & Co.      None
# 21 2025-02-11   -8.50      CHF       Starbucks Zürich      None
# 22 2025-02-11   -4.75      CHF            Tacos & Co.      None
# 23 2025-02-11  -11.90      CHF          BP Tankstelle      None
# 24 2025-02-13   -5.00      CHF                 Denner      None
# 25 2025-02-14   -5.25      CHF       Alpenblick Hütte      None
# 26 2025-02-14   -2.00      CHF       Alpenblick Hütte      None
# 27 2025-02-14  -65.00      CHF     Yoga Studio Zürich      None
# 28 2025-02-15  -26.50      CHF       Alpenblick Hütte      None
# 29 2025-02-16   -2.20      CHF       Alpenblick Hütte      None
# 30 2025-02-16  -92.50      CHF         JET Tankstelle      None
# 31 2025-02-16   -9.25      CHF        AGIP Tankstelle      None
# 32 2025-02-17   -9.30      CHF       Shell Tankstelle      None
# 33 2025-02-17 -215.00      CHF         Revolut**9876*      None
# 34 2025-02-17  -45.30      CHF  1078 Shell Winterthur      None
# 35 2025-02-18   -9.00      CHF       ETH Zürich Mensa      None
# 36 2025-02-21 -375.00      CHF         Revolut**9876*      None
#
#                                              raw_data
# 0   {"Booking Date": "2025-02-02", "Value Date": "...
# 1   {"Booking Date": "2025-02-02", "Value Date": "...
# 2   {"Booking Date": "2025-02-02", "Value Date": "...
# 3   {"Booking Date": "2025-02-02", "Value Date": "...
# 4   {"Booking Date": "2025-02-02", "Value Date": "...
# 5   {"Booking Date": "2025-02-02", "Value Date": "...
# 6   {"Booking Date": "2025-02-02", "Value Date": "...
# 7   {"Booking Date": "2025-02-03", "Value Date": "...
# 8   {"Booking Date": "2025-02-03", "Value Date": "...
# 9   {"Booking Date": "2025-02-04", "Value Date": "...
# 10  {"Booking Date": "2025-02-04", "Value Date": "...
# 11  {"Booking Date": "2025-02-04", "Value Date": "...
# 12  {"Booking Date": "2025-02-05", "Value Date": "...
# 13  {"Booking Date": "2025-02-05", "Value Date": "...
# 14  {"Booking Date": "2025-02-07", "Value Date": "...
# 15  {"Booking Date": "2025-02-08", "Value Date": "...
# 16  {"Booking Date": "2025-02-09", "Value Date": "...
# 17  {"Booking Date": "2025-02-09", "Value Date": "...
# 18  {"Booking Date": "2025-02-10", "Value Date": "...
# 19  {"Booking Date": "2025-02-10", "Value Date": "...
# 20  {"Booking Date": "2025-02-11", "Value Date": "...
# 21  {"Booking Date": "2025-02-11", "Value Date": "...
# 22  {"Booking Date": "2025-02-11", "Value Date": "...
# 23  {"Booking Date": "2025-02-11", "Value Date": "...
# 24  {"Booking Date": "2025-02-13", "Value Date": "...
# 25  {"Booking Date": "2025-02-14", "Value Date": "...
# 26  {"Booking Date": "2025-02-14", "Value Date": "...
# 27  {"Booking Date": "2025-02-14", "Value Date": "...
# 28  {"Booking Date": "2025-02-15", "Value Date": "...
# 29  {"Booking Date": "2025-02-16", "Value Date": "...
# 30  {"Booking Date": "2025-02-16", "Value Date": "...
# 31  {"Booking Date": "2025-02-16", "Value Date": "...
# 32  {"Booking Date": "2025-02-17", "Value Date": "...
# 33  {"Booking Date": "2025-02-17", "Value Date": "...
# 34  {"Booking Date": "2025-02-17", "Value Date": "...
# 35  {"Booking Date": "2025-02-18", "Value Date": "...
# 36  {"Booking Date": "2025-02-21", "Value Date": "...
